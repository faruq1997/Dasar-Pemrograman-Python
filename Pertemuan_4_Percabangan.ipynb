# %%
print('Materi hari ini tentang percabangan / Pengkondisian')
cek_disini = "Apakah ada tugas pertemuan ini?"
# Out:
# Materi hari ini tentang percabangan / Pengkondisian

# %% [markdown]
# # Apa itu percabangan?

# %% [markdown]
# Percabangan / Pengkondisian (Conditional Statement) merupakan cara yang digunakan untuk mngambil keputusan dengan kondisi tertentu. Jumlah kondisinya bisa satu, dua, atau lebih. Percabangan mengevaluasi kondisi atau ekspresi yang hasilnya benar atau salah. Kondisi atau ekspresi tersebut disebut *ekspresi boolean*.
# Hasil dari pengecekan kondisi adalah True atau False.
#
# Bila **benar (True)**, maka pernyataan yang ada di dalam blok kondisi tersebut akan dieksekusi.
#
# Bila **salah (False)**, maka blok pernyataan lain yang dieksekusi.

# %% [markdown]
# Di Python ada 3 jenis pernyataan yang digunakan untuk percabangan, yaitu sebagai berikut:
#
# ![kondisi.PNG](data:image/png;base64,...)

# %% [markdown]
# ## 1. Pernyataan if

# %% [markdown]
# ```
# # Penulisannya biasanya seperti ini:
#
# if kondisi:
#   statement()
# ```

# %% [markdown]
# Bagian `kondisi` adalah sebuah variabel / atau nilai yang bertipe data `boolean`. Baik berupa nilai `True/False` secara langsung, atau pun sebuah ekspresi logika.
#
# Jika `kondisi` bernilai `True`, maka `statements()` akan dieksekusi oleh sistem. `statements()` itu maksudnya perintah apa yang dilakukan apabila kondisinya `True`

# %%
if True:
  print('Statement ini akan dieksekusi')

if False:
  print('Statement ini tidak akan dieksekusi')

print('Statement ini akan selalu dieksekusi karena tidak termasuk pada percabangan')
# Out:
# Statement ini akan dieksekusi
# Statement ini akan selalu dieksekusi karena tidak termasuk pada percabangan

# %% [markdown]
# **Kenapa?**
#
# Karena kondisi `if` yang kedua **tidak bernilai `True`**, sehingga statement yang ada didalamnya pun tidak akan dieksekusi oleh sistem.
#
# Dan print() yang ke-3 akan selalu dieksekusi karena ia berada di luar blok kode if.
#
# **Ingat** bahwa blok kode di dalam python ditentukan oleh indentasi (tulisan yang menjorok ke kanan).
#
# ![indentasi.png](data:image/png;base64,...)

# %% [markdown]
# Selain menggunakan *boolean* secara langsung, kita juga bisa menggunakan ekspresi logika untuk percabangan.

# %%
if 10 > 5:
  # Apakah 10 > 5 ?
  print(True)
# Out:
# True

# %% [markdown]
# Contoh lain:

# %%
angka = 5

if angka > 0:
  print(angka,"lebih besar dari 0")
  # apabila 0 nya diganti jadi angka yang lebih besar dari 5, maka tidak akan tampil (False)
# Out:
# 5 lebih besar dari 0

# %% [markdown]
# ## Pernyataan If Else

# %% [markdown]
# ```
# # Penulisannya biasanya seperti ini:
#
# if tes kondisi:
#   statement untuk if
# else:
#   statement untuk else
# ```

# %%
# contoh seperti ini:
nilai = 74

print('Nilai anda adalah:', nilai, '\n')

if nilai >= 75:
  print('Selamat, anda lulus!')
else:
  print('Maaf, anda tidak lulus.')
# Out:
# Nilai anda adalah: 74
#
# Maaf, anda tidak lulus.

# %%
# contoh lain:
bilangan = -2

if bilangan >= 0:
  print("bilangan positif atau nol")
else:
  print("bilangan negatif")
# Out:
# bilangan negatif

# %% [markdown]
# Pada contoh di atas,
#
# Apabila bilangan kita beri nilai positif.
# Kemudian pada pengujian `if`, kondisinya adalah apakah bilangan >= 0 ?
#
# Hasilnya adalah benar, maka hasil yang ditampilkan adalah Positif atau Nol (`True`).
#
# Apabila kita ganti bilangan jadi -2, maka hasil pengujian `if` nya akan salah/`False` dan blok `else` yang akan dijalankan, yaitu menampilkan pesan Bilangan negatif.

# %% [markdown]
# ## Pernyataan If Elif Else

# %% [markdown]
# Pernyataan `if…elif…else` digunakan untuk menguji lebih dari 2 kondisi.
#
# Bila kondisi pada `if` benar, maka pernyataan di dalamnya yang dieksekusi.
#
# Bila salah, maka masuk ke pengujian kondisi `elif`.
#
# Terakhir bila tidak ada `if` atau `elif` yang benar, maka yang dijalankan adalah yang di blok `else`.
#
# Sintaksnya adalah seperti berikut:

# %% [markdown]
# ```
# # Penulisannya biasanya seperti ini:
#
# if tes kondisi:
#   blok pernyataan if
# elif tes kondisi:
#   blok pernyataan elif
# else:
#   blok pernyataan else
# ```

# %% [markdown]
# ![ifelifelse.PNG](data:image/png;base64,...)

# %% [markdown]
# Contoh yang paling umum digunakan untuk kasus percabangan `if..elif..else` adalah menentukan grade nilai suatu mahasiswa.
#
# Jika nilainya sekian, dia dapat predikat A. Sedangkan jika nilainya sekian maka predikatnya adalah B, dan seterusnya.
#
# Berikut ini rules yang akan kita gunakan:
#
# Predikat A untuk nilai >= 90
# Predikat B untuk nilai >= 80 < 90
# Predikat C untuk nilai >= 60 < 80
# Predikat D untuk nilai >= 40 < 60
# Selain itu, maka predikat E.
# Dari 5 rule diatas, kita akan menggunakan satu if, 3 elif, dan 1 else.
#
# Perhatikan contoh berikut:

# %%
nilai = int(input('Masukkan nilai mahasiswa: '))

if nilai >= 88:
  print('Predikat A')
elif nilai >= 75:
  print('Predikat B')
elif nilai >= 60:
  print('Predikat C')
elif nilai >= 40:
  print('Predikat D')
else:
  print('Predikat E')
# Out:
# Masukkan nilai mahasiswa: 75
# Predikat B

# %% [markdown]
# **Contoh lain:**

# %%
bilangan = 1.1

if bilangan>0:
  print("bilangan positif")
elif bilangan==0:
  print("nol")
else:
  print("bilangan negatif")
# Out:
# bilangan positif

# %% [markdown]
# Pada contoh di atas, bilangan kita beri nilai 1.1
#
# Pada pengujian `if`, kondisinya adalah apakah bilangan > 0? Hasilnya benar, maka yang ditampilkan adalah pesan Bilangan positif.
#
# Bila nilai bilangan kita ganti menjadi 0, maka yang akan bernilai benar adalah pernyataan `elif`.
#
# Bila kita mengganti bilangan jadi minus, maka kondisi if dan elif salah, dan yang dijalankan adalah blok `else`.

# %% [markdown]
# **Catatan:** Python mengasumsikan bahwa nilai selain nol dan selain tipe None sebagai nilai True, dan yang nilai nol dan None sebagai False.

# %% [markdown]
# ## Studi Kasus
#
# Misal ada studi kasus seperti ini:
#
# ![studi kasus percabangan.PNG](data:image/png;base64,...)
#
# Masukkan / input yang dirancang seperti ini:
#
# ![studi kasus percabangan -inputan.PNG](data:image/png;base64,...)
#
# Dengan output yang diharapkan seperti ini:
#
# ![studi kasus percabangan -output.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Kita rancang dahulu inputan yang diminta -> proses apa yang terjadi -> rancang output

# %%
#Input
pembeli=input("Input Nama Pembeli : ")
no_hp=input("Input No. Handphone : ")
jurusan=input("Input Jurusan [SBY/BL/LMP] : ")

#Proses
if jurusan=="SBY" or jurusan=="sby":
  namajurusan="Surabaya"
  harga=300000
elif jurusan=="BL" or jurusan=="bl":
  namajurusan="Bali"
  harga=350000
else :
  namajurusan="Lampung"
  harga=500000

#Input Jumlah Beli
jumlah=int(input("Masukkan Jumlah Beli : "))

#proses potongan
if jumlah>=3 :
  potongan=(jumlah*harga)*0.1
else:
  potongan=0
  total=(jumlah*harga)-potongan

#Cetak Hasil
print("------------------------------------")
print(" PENJUALAN TIKET BUS")
print(" XYZ")
print("------------------------------------")
print("Nama Pembeli : "+str(pembeli))
print("No. Handphone : "+str(no_hp))
print("Kode Jurusan yang dipilih : "+str(jurusan))
print("Nama Kota Tujuan : "+str(namajurusan))
print("Harga : ",+(harga))
print("Jumlah Beli : ",+(jumlah))
print("------------------------------------")
print("potongan yang didapat : ",+(potongan))
print("Total Bayar : ",+(total))
ubay=int(input("Masukkan Uang Bayar : "))
uangkembali=ubay-total
print("Uang Kembali : ",+uangkembali)
# Out:
# Input Nama Pembeli : Sopandi
# Input No. Handphone : 082297117049
# Input Jurusan [SBY/BL/LMP] : SBY
# Masukkan Jumlah Beli : 3
# ------------------------------------
#  PENJUALAN TIKET BUS
#  XYZ
# ------------------------------------
# Nama Pembeli : Sopandi
# No. Handphone : 082297117049
# Kode Jurusan yang dipilih : SBY
# Nama Kota Tujuan : Surabaya
# Harga :  300000
# Jumlah Beli :  3
# ------------------------------------
# potongan yang didapat :  90000.0
# Total Bayar :  500000
# Masukkan Uang Bayar : 1000000
# Uang Kembali :  500000

# %% [markdown]
# ## Studi Kasus 2

# %% [markdown]
# Ada perintah seperti ini:
#
# ![studi kasus 2.PNG](data:image/png;base64,...)

# %%
# input
nim = input("Masukkan NIM kamu: ")
nama = input("Masukkan Nama kamu: ")
jurusan = input("Masukkan jurusan / prodi kamu [SI/TI]: ")

# proses
if jurusan =="SI" or jurusan =="si":
  nama_jurusan = "Sistem Informasi"
  biaya_kuliah = 4800000
elif jurusan =="TI" or jurusan=="ti":
  nama_jurusan = "Teknik Informatika"
  biaya_kuliah = 5000000

# output
print("Nim kamu:", nim)
print("Nama kamu: "+ str(nama))
print("Jurusan yang kamu ambil adalah",nama_jurusan,"[",str(jurusan),"]")
print("Biaya kuliah persemesternya adalah",biaya_kuliah)
# Out:
# Masukkan NIM kamu: 11180920
# Masukkan Nama kamu: Faruq Aziz
# Masukkan jurusan / prodi kamu [SI/TI]: SI
# Nim kamu: 11180920
# Nama kamu: Faruq Aziz
# Jurusan yang kamu ambil adalah Sistem Informasi [ SI ]
# Biaya kuliah persemesternya adalah 4800000

# %%
print(cek_disini)
if cek_disini != None:
  print(True)
else:
  print(False)
# Out:
# Apakah ada tugas pertemuan ini?
# True

# %% [markdown]
# ![tugas_percabangan.png](data:image/png;base64,...)

# %% [markdown]
# Input dan Output seperti ini:
#
# ![tugas_percabangan-inputoutput.PNG](data:image/png;base64,...)

# %% [markdown]
# # Referensi Terkait
#
#
# 1.   Modul Universitas Nusa Mandiri [Bagian Percabangan]
# 2.   [Jago Ngoding](https://jagongoding.com/python/dasar/percabangan/)
