# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
menu = ["Apel", "Semangka", "Melon", "Manggis", "Kurma"]

Buah = input("Masukkan buah apa yang mau kamu beli? ")
for produk in menu:
  if produk.lower() == Buah.lower():
    print("Silahkan lakukan pembayaran")
    break
else:
  print("Maaf buah yang dicari tidak ditemukan")
# Out:
# Masukkan buah apa yang mau kamu beli? Kurma
# Silahkan lakukan pembayaran

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
kuncinya = ['Seblak', 'Baso', 'Burger King']

doi_ngambek = input("Tebak Makanan Kesukaan Aku Apa Mwueheheh")

for p in (kuncinya):
  if p.lower() == doi_ngambek.lower():
    print('aku Sayang Kamu Dechh Bener Muachhhh')
    break
  else:
    print('Maaf Kamu Terlalu Baik Buat Aku :(')
# Out:
# Tebak Makanan Kesukaan Aku Apa MwuehehehWarteg
# Maaf Kamu Terlalu Baik Buat Aku :(
# Maaf Kamu Terlalu Baik Buat Aku :(
# Maaf Kamu Terlalu Baik Buat Aku :(

# %%
ulang=2
for i in range(ulang):
  print ("data ke - " + str(i+1))
  nama=input("Masukkan Nim anda : ")
  uts=int(input("Masukkan Nilai UTS :"))
  uas=int(input("Masukkan Nilai UAS : "))
  print("NIm anda adalah %s nilai UTS anda %i nilai UTS anda %i" % (nama,uts,uas))
  print("-------------------------------------\n")
# Out:
# data ke - 1
# Masukkan Nim anda : test
# Masukkan Nilai UTS :40
# Masukkan Nilai UAS : 70
# NIm anda adalah test nilai UTS anda 40 nilai UTS anda 70
# -------------------------------------
#
# data ke - 2
# Masukkan Nim anda : yyyy
# Masukkan Nilai UTS :60
# Masukkan Nilai UAS : 50
# NIm anda adalah yyyy nilai UTS anda 60 nilai UTS anda 50
# -------------------------------------

# %% [markdown]
# # Gerobak Fried Chicken

# %%
print("="*32)
print("     GEROBAK FRIED CHICKENN ")
print("-"*32)
print(" Kode   Jenis Potong     Harga")
print("-"*32)
print("  D         Dada       Rp. 2500")
print("  P         Paha       Rp. 2000")
print("  S         Sayap      Rp. 1500")
print("="*32)
banyakjenis = int(input("Masukan Banyak Jenis : "))
kode = []
jenispotong = []
jumlahbeli = []
harga = []
jumlah = []
x = 0
jumlahbayar=0
while x < banyakjenis:
    print("Jenis ke :",x+1)
    kode.append(input("Kode Potong [D/P/S] : "))
    jumlahbeli.append(int(input("Banyak Potong : ")))

    if kode[x] == "D" or kode[x] == "d":
        jenispotong.append ("Dada")
        harga.append ("2500")
        jumlah.append (jumlahbeli[x]*int(2500))

    elif kode[x] == "P" or kode[x] == "p":
        jenispotong.append ("Paha")
        harga.append ("2000")
        jumlah.append (jumlahbeli[x]*int(2000))

    elif kode[x] == "S" or kode[x] == "s":
        jenispotong.append ("Sayap")
        harga.append ("1500")
        jumlah.append (jumlahbeli[x]*int(1500))

    else:
        jenispotong.append ("Kode Salah ! ")
        harga.append ("0")
        jumlah.append (jumlahbeli[x]*int(0))
        
    jumlahbayar += jumlah[x]
    x += 1

print ("=================================================================")
print ("| No | Jenis Potong | Harga Satuan | Banyak Beli | Jumlah Harga |")
print ("=================================================================")

a = 0
diskon = jumlahbayar * 10/100
subtotal = jumlahbayar+diskon

while a < banyakjenis:
    print ("| %i  |    %s\t    |     %s     |      %i      | Rp %i\t|" % (a+1, jenispotong[a], harga[a], jumlahbeli[a], jumlah[a]))
    print ("|---------------------------------------------------------------|") 
    a=a+1

print("|\t\t\t\t   Jumlah Bayar  | Rp",jumlahbayar,"\t|")
print("|---------------------------------------------------------------|")
print("|\t\t\t\t   Pajak 10%     | Rp",int(diskon),"\t|")
print("|---------------------------------------------------------------|")
print("|\t\t\t\t   Total Bayar   | Rp",int(subtotal),"\t|")
print ("=================================================================")
# Out:
# ================================
#      GEROBAK FRIED CHICKENN
# --------------------------------
#  Kode   Jenis Potong     Harga
# --------------------------------
#   D         Dada       Rp. 2500
#   P         Paha       Rp. 2000
#   S         Sayap      Rp. 1500
# ================================
# Masukan Banyak Jenis : 2
# Jenis ke : 1
# Kode Potong [D/P/S] : s
# Banyak Potong : 1
# Jenis ke : 2
# Kode Potong [D/P/S] : d
# Banyak Potong : 2
# =================================================================
# | No | Jenis Potong | Harga Satuan | Banyak Beli | Jumlah Harga |
# =================================================================
# | 1  |    Sayap	    |     1500     |      1      | Rp 1500	|
# |---------------------------------------------------------------|
# | 2  |    Dada	    |     2500     |      2      | Rp 5000	|
# |---------------------------------------------------------------|
# |				   Jumlah Bayar  | Rp 6500 	|
# |---------------------------------------------------------------|
# |				   Pajak 10%     | Rp 650 	|
# |---------------------------------------------------------------|
# |				   Total Bayar   | Rp 7150 	|
# =================================================================
